# %%
import pylotec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pylotec
#
# File ~/Desktop/Pylotec/pylotec.py:11
#       8 import plotly.graph_objects as go
#      10 import matplotlib.image as mgimg
# ---> 11 from pillow import Image
#      12 from scipy.fft import fft
#      14 import cmath
#
# ModuleNotFoundError: No module named 'pillow'

# %%
pylotec.load_uff()
# Out:
# 2 files found in the Data Directory. Please type:
#
# 0 for Diatomischer Kristall Kurs SoSe 23.uff
# 1 for Diatomischer Kristall M2.uff
# 100%|██████████| 26/26 [00:02<00:00, 10.87it/s]
# The X, Y, Z nodes, forces and velocities are now saved under Data/NumPyArrays.

# %%
pylotec.calculate_IRFs()
# Out:
# Diatomischer Kristall Kurs SoSe 23
# Diatomischer Kristall M2
# 'All IRFs were saved to Data/NumPyArrays.'

# %%
import pylotec

IRFs, Peaks2 = pylotec.meanspec(thresh=-9, prom=0.5, saveToFile=True)
# Out:
# 2 files found in the Data Directory. Please type:
#
# 0 for Diatomischer Kristall Kurs SoSe 23.uff
# 1 for Diatomischer Kristall M2.uff

# %%
pylotec.plot_modes(IRFs, Peaks2, fmin=1000)
# Out:
# 2 files found in the Data Directory. Please type:
#
# 0 for Diatomischer Kristall Kurs SoSe 23.uff
# 1 for Diatomischer Kristall M2.uff
# 'Modes saved (Real part)!'
